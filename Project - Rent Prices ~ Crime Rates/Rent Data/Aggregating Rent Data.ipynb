# %%
import pandas as pd

# %%
rent_12 = pd.read_csv('Rent_2012.csv')
rent_12
# Out:
#      Unnamed: 0  Unnamed: 0.1  State           CBSASub  \
# 0             0             0      1  METRO11500M11500
# 1             1             1      1  METRO12220M12220
# 2             2             2      1  METRO13820M13820
# 3             3             5      1  METRO17980M17980
# 4             4             6      1  METRO19460M19460
# ..          ...           ...    ...               ...
# 408         453          2613     72  METRO41980N72923
# 409         454          2614     72  METRO49500M49500
# 410         455          2615     72  NCNTY72923N72923
# 411         456          2616     78  NCNTY78010N78010
# 412         457          2617     78  NCNTY78923N78923
#
#                                               Areaname  Rent50_0  Rent50_1  \
# 0                              Anniston-Oxford, AL MSA       493       544
# 1                               Auburn-Opelika, AL MSA       487       580
# 2             Birmingham-Hoover, AL HUD Metro FMR Area       656       729
# ...

# %%
rent_12.groupby(['Areaname']).mean()
# Out:
#                                                    Unnamed: 0  Unnamed: 0.1  \
# Areaname
# Abilene, TX MSA                                           362          2124
# Aguadilla-Isabela-San Sebastián, PR MSA                   444          2604
# Akron, OH MSA                                             296          1730
# Albany, GA MSA                                             98           337
# Albany-Schenectady-Troy, NY MSA                           265          1556
# ...                                                       ...           ...
# York-Hanover, PA MSA                                      335          1912
# York-Kittery-South Berwick, ME HUD Metro FMR Area         181           975
# Youngstown-Warren-Boardman, OH HUD Metro FMR Area         311          1748
# Yuba City, CA MSA                                          56           192
# Yuma, AZ MSA                                               20            88
#
# ...

# %%
rent_12.to_csv('Area_12.csv')
