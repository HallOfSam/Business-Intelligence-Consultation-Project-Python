# %%
import pandas as pd

# %%
crime_report = pd.read_csv('crime_report.csv')

# %%
rent_2012 = pd.read_csv('Area_12.csv')

# %%
crime_report = crime_report[crime_report['agency_jurisdiction'].notna()]

# %%
list_of_cities = crime_report.agency_jurisdiction.unique()
list_of_cities
# Out:
# array(['Albuquerque, NM', 'Arlington, TX', 'Atlanta, GA', 'Aurora, CO',
#        'Austin, TX', 'Baltimore, MD', 'Boston, MA', 'Buffalo, NY',
#        'Charlotte, NC', 'Chicago, IL', 'Cincinnati, OH', 'Cleveland, OH',
#        'Columbus, OH', 'Dallas, TX', 'Denver, CO', 'Detroit, MI',
#        'El Paso, TX', 'Fort Worth, TX', 'Fresno, CA', 'Honolulu, HI',
#        'Houston, TX', 'Indianapolis, IN', 'Jacksonville, FL',
#        'Kansas City, MO', 'Las Vegas, NV', 'Long Beach, CA',
#        'Los Angeles, CA', 'Louisville, KY', 'Memphis, TN', 'Mesa, AZ',
#        'Miami, FL', 'Milwaukee, WI', 'Minneapolis, MN', 'Nashville, TN',
#        'New Orleans, LA', 'New York, NY', 'Newark, NJ', 'Oakland, CA',
#        'Oklahoma City, OK', 'Omaha, NE', 'Orlando, FL',
#        'Philadelphia, PA', 'Phoenix, AZ', 'Pittsburgh, PA',
#        'Portland, OR', 'Raleigh, NC', 'Sacramento, CA',
#        'Salt Lake City, UT', 'San Antonio, TX', 'San Diego, CA',
# ...

# %%
states=[]
for i in range(len(list_of_cities)):
    size = len(list_of_cities[i])
    states.append(list_of_cities[i][size-2:])
    
states= states*11
# Out:
# ['NM',
#  'TX',
#  'GA',
#  'CO',
#  'TX',
#  'MD',
#  'MA',
#  'NY',
#  'NC',
#  'IL',
#  'OH',
#  'OH',
#  'OH',
#  'TX',
#  'CO',
#  'MI',
#  'TX',
#  'TX',
#  'CA',
#  'HI',
#  'TX',
#  'IN',
#  'FL',
#  'MO',
#  'NV',
#  'CA',
#  'CA',
#  'KY',
#  'TN',
#  'AZ',
#  'FL',
#  'WI',
#  'MN',
#  'TN',
#  'LA',
#  'NY',
#  'NJ',
#  'CA',
#  'OK',
#  'NE',
#  'FL',
#  'PA',
#  'AZ',
#  'PA',
#  'OR',
#  'NC',
#  'CA',
#  'UT',
#  'TX',
#  'CA',
#  'CA',
#  'CA',
#  'WA',
#  'MO',
#  'FL',
#  'AZ',
#  'OK',
#  'VA',
#  'DC',
#  'KS',
#  'NM',
#  'TX',
#  'GA',
#  'CO',
#  'TX',
#  'MD',
#  'MA',
#  'NY',
#  'NC',
#  'IL',
#  'OH',
#  'OH',
#  'OH',
#  'TX',
#  'CO',
#  'MI',
#  'TX',
#  'TX',
#  'CA',
#  'HI',
#  'TX',
#  'IN',
#  'FL',
#  'MO',
#  'NV',
#  'CA',
#  'CA',
#  'KY',
#  'TN',
#  'AZ',
#  'FL',
#  'WI',
#  'MN',
#  'TN',
#  'LA',
#  'NY',
#  'NJ',
#  'CA',
#  'OK',
#  'NE',
#  'FL',
#  'PA',
#  'AZ',
#  'PA',
#  'OR',
#  'NC',
#  'CA',
#  'UT',
#  'TX',
#  'CA',
#  'CA',
# ...

# %%
crime_report['state']= states

# %%
crime_report
# Out:
#      Unnamed: 0  Unnamed: 0.1  report_year agency_code agency_jurisdiction  \
# 0             0          2070         2005     NM00101     Albuquerque, NM
# 1             1          2071         2005     TX22001       Arlington, TX
# 2             2          2072         2005     GAAPD00         Atlanta, GA
# 3             3          2073         2005     CO00101          Aurora, CO
# 4             4          2074         2005     TX22701          Austin, TX
# ..          ...           ...          ...         ...                 ...
# 743         753          2823         2015     AZ01003          Tucson, AZ
# 744         754          2824         2015     OK07205           Tulsa, OK
# 745         755          2825         2015     VA12800  Virginia Beach, VA
# 746         756          2826         2015     DCMPD00      Washington, DC
# 747         757          2827         2015     KS08703         Wichita, KS
#
# ...

# %%
for i in range(0,len(list_of_cities)-1):
    
    crime_report['state'] = list_of_cities[i][len(list_of_cities[i]) - 2 : ]
crime_report
# Out:
#      Unnamed: 0  Unnamed: 0.1  report_year agency_code agency_jurisdiction  \
# 0             0          2070         2005     NM00101     Albuquerque, NM
# 1             1          2071         2005     TX22001       Arlington, TX
# 2             2          2072         2005     GAAPD00         Atlanta, GA
# 3             3          2073         2005     CO00101          Aurora, CO
# 4             4          2074         2005     TX22701          Austin, TX
# ..          ...           ...          ...         ...                 ...
# 743         753          2823         2015     AZ01003          Tucson, AZ
# 744         754          2824         2015     OK07205           Tulsa, OK
# 745         755          2825         2015     VA12800  Virginia Beach, VA
# 746         756          2826         2015     DCMPD00      Washington, DC
# 747         757          2827         2015     KS08703         Wichita, KS
#
# ...

# %%
for city in list_of_cities:
    for i in range(0, len(rent_2012)):
        if city in rent_2012['Areaname'].iloc[i]:
            print(rent_2012['Areaname'].iloc[i])
# Out:
# Albuquerque, NM MSA
# Washington-Arlington-Alexandria, DC-VA-MD HUD Metro FMR Area
# Fort Worth-Arlington, TX HUD Metro FMR Area
# Atlanta-Sandy Springs-Marietta, GA HUD Metro FMR Area
# Denver-Aurora-Broomfield, CO MSA
# Austin-Round Rock-San Marcos, TX MSA
# Baltimore-Towson, MD HUD Metro FMR Area
# Boston-Cambridge-Quincy, MA-NH HUD Metro FMR Area
# Buffalo-Niagara Falls, NY MSA
# Charlotte-Gastonia-Rock Hill, NC-SC HUD Metro FMR Area
# Charlottesville, VA MSA
# Chicago-Joliet-Naperville, IL HUD Metro FMR Area
# Cincinnati-Middleton, OH-KY-IN HUD Metro FMR Area
# Cleveland-Elyria-Mentor, OH MSA
# Cleveland, TN MSA
# Columbus, GA-AL MSA
# Columbus, IN MSA
# Columbus, OH HUD Metro FMR Area
# Dallas, TX HUD Metro FMR Area
# Denver-Aurora-Broomfield, CO MSA
# Detroit-Warren-Livonia, MI HUD Metro FMR Area
# El Paso, TX MSA
# Fort Worth-Arlington, TX HUD Metro FMR Area
# Fresno, CA MSA
# Honolulu, HI MSA
# Houston-Baytown-Sugar Land, TX HUD Metro FMR Area
# ...

# %%
crime_report.to_csv('Crime_with_states.csv')
