# %%
import pandas as pd

# %%
df = pd.read_csv('2010.csv')
df
# Out:
#                                      Label (Grouping)  \
# 0                           Population 18 to 24 years
# 1                      Less than high school graduate
# 2         High school graduate (includes equivalency)
# 3                  Some college or associate's degree
# 4                         Bachelor's degree or higher
# 5                        Population 25 years and over
# 6                                 Less than 9th grade
# 7                       9th to 12th grade, no diploma
# 8         High school graduate (includes equivalency)
# 9                             Some college, no degree
# 10                                 Associate's degree
# 11                                  Bachelor's degree
# 12                    Graduate or professional degree
# 13             Percent high school graduate or higher
# 14                Percent bachelor's degree or higher
# 15                          Population 25 to 34 years
# ...

# %%
df = df[df.columns.drop(list(df.filter(regex='Male')))]
df = df[df.columns.drop(list(df.filter(regex='Female')))]
df
# Out:
#                                      Label (Grouping)  \
# 0                           Population 18 to 24 years
# 1                      Less than high school graduate
# 2         High school graduate (includes equivalency)
# 3                  Some college or associate's degree
# 4                         Bachelor's degree or higher
# 5                        Population 25 years and over
# 6                                 Less than 9th grade
# 7                       9th to 12th grade, no diploma
# 8         High school graduate (includes equivalency)
# 9                             Some college, no degree
# 10                                 Associate's degree
# 11                                  Bachelor's degree
# 12                    Graduate or professional degree
# 13             Percent high school graduate or higher
# 14                Percent bachelor's degree or higher
# 15                          Population 25 to 34 years
# ...

# %%
df1=df.drop(df.index[16:27])

# %%
df1
# Out:
#                                      Label (Grouping)  \
# 0                           Population 18 to 24 years
# 1                      Less than high school graduate
# 2         High school graduate (includes equivalency)
# 3                  Some college or associate's degree
# 4                         Bachelor's degree or higher
# 5                        Population 25 years and over
# 6                                 Less than 9th grade
# 7                       9th to 12th grade, no diploma
# 8         High school graduate (includes equivalency)
# 9                             Some college, no degree
# 10                                 Associate's degree
# 11                                  Bachelor's degree
# 12                    Graduate or professional degree
# 13             Percent high school graduate or higher
# 14                Percent bachelor's degree or higher
# 15                          Population 25 to 34 years
# ...

# %%
df1=df1.drop(df.index[15])
df1
# Out:
#                                      Label (Grouping)  \
# 0                           Population 18 to 24 years
# 1                      Less than high school graduate
# 2         High school graduate (includes equivalency)
# 3                  Some college or associate's degree
# 4                         Bachelor's degree or higher
# 5                        Population 25 years and over
# 6                                 Less than 9th grade
# 7                       9th to 12th grade, no diploma
# 8         High school graduate (includes equivalency)
# 9                             Some college, no degree
# 10                                 Associate's degree
# 11                                  Bachelor's degree
# 12                    Graduate or professional degree
# 13             Percent high school graduate or higher
# 14                Percent bachelor's degree or higher
# 27  POVERTY RATE FOR THE POPULATION 25 YEARS AND O...
# ...

# %%
df1.to_csv('clean2010.csv')
